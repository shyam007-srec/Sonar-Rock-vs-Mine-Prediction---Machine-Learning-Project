# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/red-wine-quality-cortez-et-al-2009'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/red-wine-quality-cortez-et-al-2009/winequality-red.csv

# %% [markdown]
# # Import the Requre Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Data Loading

# %%
#load the requre data as df

df = pd.read_csv('/kaggle/input/red-wine-quality-cortez-et-al-2009/winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Finding the Correlation Between features
plt.figure(figsize=(10,5))
sns.heatmap(data=df.select_dtypes(include=['number']).corr(), annot=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x='quality')
plt.title('Count Plot for Quality')
plt.show()

# %%
plt.figure(figsize=(9,5))
sns.lineplot(data=df, x="quality", y='alcohol')
plt.title('Quality vs Alcohol ')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(9,5))
sns.lineplot(data=df, x="free sulfur dioxide", y='total sulfur dioxide')
plt.title('Quality vs Alcohol ')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(9,5))
sns.lineplot(data=df, x="pH", y='alcohol')
plt.title('Quality vs Alcohol ')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.show()

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
plt.figure(figsize=(5,4))
sns.boxplot(data=df[['free sulfur dioxide','total sulfur dioxide','residual sugar']])
plt.xticks(rotation=45)
plt.grid()

# %%
df.drop(df[df['residual sugar'] > 10].index, axis=0, inplace=True)

# %%
df.drop(df[df['total sulfur dioxide'] > 155].index, inplace=True)

# %%
df.drop(df[df['free sulfur dioxide']>55].index,axis=0,inplace=True)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df)
plt.title('Outliers of the wine data')
plt.xticks(rotation=90)
plt.show()

# %%
numeric_col = df.select_dtypes(include=['float64','int64']).columns

for col in numeric_col:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    df = df[ (df[col] >= (Q1 - 1.5*IQR)) & (df[col]<= (Q3 + 1.5*IQR))]

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df)
plt.title('Outliers of the wine data')
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(data=df, x='total sulfur dioxide', y='free sulfur dioxide')
# Out:
# <Axes: xlabel='total sulfur dioxide', ylabel='free sulfur dioxide'>

# %%
plt.figure(figsize=(9,5))
sns.scatterplot(data=df, x='citric acid', y='fixed acidity')
plt.title('Quality vs Alcohol ')
plt.show()

# %%
sns.pairplot(data=df, vars=['alcohol', 'residual sugar', 'total sulfur dioxide', 'free sulfur dioxide'], hue='quality')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create correlation matrix for numeric columns only
corr_matrix = df.select_dtypes(include=['number']).corr()

# Plot heatmap
plt.figure(figsize=(10, 5))
sns.heatmap(
    data=corr_matrix,
    annot=True,            # Show values
    fmt=".2f",            # Format to 2 decimal places
    cmap='coolwarm',      # Color scheme
    vmin=-1, vmax=1,      # Fix color range from -1 to 1
    mask=np.triu(np.ones_like(corr_matrix))  # Mask upper triangle (optional)
)
plt.title('Correlation Heatmap (Numeric Columns Only)')
plt.xticks(rotation=45)   # Rotate x-axis labels
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='quality', palette='rocket')
plt.title("Wine Quality Distribution")
plt.xlabel("Quality Score")
plt.ylabel("Count")
plt.show()

# %%
fig,ax = plt.subplots(2,2)

sns.set_style('ticks')
sns.lineplot(data=df, x="quality", y='alcohol', ax=ax[0,0])
ax[0,0].set_title('Quality vs Alcohol ')



sns.lineplot(data=df, x="pH", y='alcohol', ax=ax[0,1])
ax[0,1].set_title('pH vs Alcohol ')


sns.lineplot(data=df, x="free sulfur dioxide", y='total sulfur dioxide', ax=ax[1,0])
ax[1,0].set_title('free sulfur dioxide vs total sulfur dioxide')

sns.histplot(data=df['pH'], kde=True, ax=ax[1,1] , bins=20)
ax[1,1].set_title('Distribution of Acidity (pH)')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x='residual sugar', y='density')
plt.title('Sugar (Residual Sugar) vs. Density')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df, x='quality', y='volatile acidity', palette='magma', errorbar=('ci',False))
plt.title('Quality vs Volatile acidity')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Plot (adjust columns as needed)
ax.scatter(
    df['alcohol'], 
    df['pH'], 
    df['residual sugar'], 
    c=df['quality'],  # Color by quality
    cmap='viridis',
    s=50  # Marker size
)

# Labels
ax.set_xlabel('Alcohol %', fontsize=12)
ax.set_ylabel('pH', fontsize=12)
ax.set_zlabel('Residual Sugar', fontsize=12)
ax.set_title('3D Plot: Alcohol, pH, and Sugar', fontsize=14)

# Colorbar (for quality)
cbar = plt.colorbar(ax.scatter([], [], [], c=[], cmap='viridis'))
cbar.set_label('Quality', rotation=270, labelpad=15)

plt.tight_layout()
plt.show()

# %%
import plotly.express as px

fig = px.scatter_3d(
    df, 
    x='alcohol', 
    y='pH', 
    z='residual sugar', 
    color='quality',
    title='Interactive 3D Wine Analysis',
    labels={'alcohol': 'Alcohol %', 'pH': 'pH Level', 'residual sugar': 'Sugar (g/L)'},
    opacity=0.7,
    hover_data=['volatile acidity']  # Extra info on hover
)

fig.update_layout(margin=dict(l=0, r=0, b=0, t=30))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Fill Missing Values with SimpleImputer

# %%
from sklearn.impute import SimpleImputer
import pandas as pd
import seaborn as sns

df_1 = sns.load_dataset("titanic")[['age', 'sex', 'fare']]

# %%
df_1.isna().sum()
# Out:
# age     177
# sex       0
# fare      0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
df_1['age'] = imputer.fit_transform(df_1[['age']])

# %%
sns.boxplot(data=df_1['age'])
# Out:
# <Axes: >

# %%
numeric_col = df_1.select_dtypes(include=['float64','int64']).columns

for col in numeric_col:
    Q1 = df_1[col].quantile(0.25)
    Q3 = df_1[col].quantile(0.75)
    IQR = Q3 - Q1
    df_1= df_1[ (df_1[col] >= (Q1 - 1.5*IQR)) & (df_1[col]<= (Q3 + 1.5*IQR))]

# %%
sns.boxplot(data=df_1)
# Out:
# <Axes: >

# %% [markdown]
# # Groupby quality

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['quality'].value_counts()
# Out:
# quality
# 5    487
# 6    468
# 7    128
# 4     32
# Name: count, dtype: int64

# %% [markdown]
# # Split Features & Target

# %%
X = df.drop('quality', axis=1)
y = df['quality']

# %%
num_df = df.select_dtypes(include=['number']).columns

# %%
num_df
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

numerical_feature = num_df

numeric_pipline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),# fit the missing numerrical number
    ('scaler',StandardScaler())# scaler features
])

# %% [markdown]
# # Combine Both with ColumnTransformer

# %%
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(transformers=[
    ('num',numeric_pipline,numerical_feature)
])

# %% [markdown]
# # Create Final Pipeline with Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

model_pipeline = Pipeline([
    ('preprocessing', preprocessor),
    ('classifier',RandomForestClassifier)
])

# %% [markdown]
# # Train / Test Split
